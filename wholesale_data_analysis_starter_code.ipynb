# %% [markdown]
# ## Part 1: Explore the Data
#
# Import the data and use Pandas to learn more about the dataset.

# %%
import pandas as pd

df = pd.read_csv('Resources/client_dataset.csv')
df.head()
# Out:
#        first      last                    job               phone  \
# 0     Donald   Harding           Immunologist  793-904-7725x39308
# 1    Tiffany     Myers        Music therapist    201.442.4543x942
# 2    Shannon    Watson           Immunologist   687.737.9424x8503
# 3     Nathan     Baker  Accounting technician    827-788-8123x012
# 4  Christina  Schwartz           Chiropractor        265-829-3643
#
#                                  email  client_id  order_id  order_date  \
# 0     harding.donald.7185@sullivan.com      58515   8953482  2023-04-28
# 1    myers.t.6537@ferguson-johnson.net      37609   8069089  2023-05-19
# 2                swatson8146@payne.net      57113   1902144  2023-01-29
# 3               bakernathan@benson.com      46554   9031802  2023-04-25
# 4  christinaschwartz9252@mcconnell.com      92089   1322274  2023-05-28
#
#    order_week  order_year         item_id     category         subcategory  \
# ...

# %%
# View the column names in the df
df.columns
# Out:
# Index(['first', 'last', 'job', 'phone', 'email', 'client_id', 'order_id',
#        'order_date', 'order_week', 'order_year', 'item_id', 'category',
#        'subcategory', 'unit_price', 'unit_cost', 'unit_weight', 'qty',
#        'line_number'],
#       dtype='object')

# %%
# Use the describe function to gather some basic statistics
df.describe()
# Out:
#           client_id      order_id    order_week    order_year    unit_price  \
# count  54639.000000  5.463900e+04  54639.000000  54639.000000  54639.000000
# mean   54837.869416  5.470190e+06     11.359139   2022.993064    136.267207
# std    25487.438231  2.599807e+06      7.023499      0.082997    183.873135
# min    10033.000000  1.000886e+06      1.000000   2022.000000      0.010000
# 25%    33593.000000  3.196372e+06      6.000000   2023.000000     20.800000
# 50%    53305.000000  5.496966e+06     11.000000   2023.000000     68.310000
# 75%    78498.000000  7.733869e+06     17.000000   2023.000000    173.160000
# max    99984.000000  9.998480e+06     52.000000   2023.000000   1396.230000
#
#           unit_cost   unit_weight           qty   line_number
# count  54639.000000  54639.000000  5.463900e+04  54639.000000
# mean      99.446073      5.004116  5.702646e+02      2.979667
# std      133.164267      5.326599  1.879552e+04      2.436320
# ...

# %%
# Use this space to do any additional research
# and familiarize yourself with the data.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54639 entries, 0 to 54638
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   first        54639 non-null  object
#  1   last         54639 non-null  object
#  2   job          54639 non-null  object
#  3   phone        54639 non-null  object
#  4   email        54639 non-null  object
#  5   client_id    54639 non-null  int64
#  6   order_id     54639 non-null  int64
#  7   order_date   54639 non-null  object
#  8   order_week   54639 non-null  int64
#  9   order_year   54639 non-null  int64
#  10  item_id      54639 non-null  object
#  11  category     54639 non-null  object
#  12  subcategory  54639 non-null  object
#  13  unit_price   54639 non-null  float64
#  14  unit_cost    54639 non-null  float64
#  15  unit_weight  54639 non-null  float64
#  16  qty          54639 non-null  int64
#  17  line_number  54639 non-null  int64
# ...

# %%
# What three item categories had the most entries?
#number_of_unique_categories = df['category'].nunique()
#number_of_unique_categories """=5"""
#df['category'].unique() """['decor', 'consumables', 'software', 'furniture', 'electronics']"""
df["category"].value_counts().head(3)
# Out:
# category
# consumables    23538
# furniture      11915
# software        8400
# Name: count, dtype: int64

# %%
# For the category with the most entries, which subcategory had the most entries?
#bathroom supplies


Category_w_most_entries = df["category"].value_counts().head(1)

#consumables

df_category_w_only_most_entries = df[df["category"] == "consumables"]
#df_category_w_only_most_entries.head()

df["subcategory"].value_counts().head(1)
# Out:
# subcategory
# bathroom supplies    6424
# Name: count, dtype: int64

# %%
# Which five clients had the most entries in the data?
#Christopher    1090
#Michael        1047
#William         982
#John            959
#Jennifer        902

df["client_id"].value_counts()
# Out:
# client_id
# 33615    220
# 66037    211
# 46820    209
# 38378    207
# 24741    207
#         ...
# 70734      4
# 32001      4
# 77583      3
# 76017      3
# 94987      1
# Name: count, Length: 999, dtype: int64

# %%
# Out:
# first          ChristopherChristopherChristopherChristopherCh...
# last           RhodesRhodesRhodesRhodesRhodesRhodesRhodesRhod...
# job            Engineer, manufacturing systemsEngineer, manuf...
# phone          001-319-767-5123001-319-767-5123001-319-767-51...
# email          rhodeschristopher9096@alvarado.inforhodeschris...
# client_id                                                2595565
# order_id                                               239754231
# order_date     2023-03-092023-04-162023-01-032023-02-202023-0...
# order_week                                                   305
# order_year                                                 70805
# item_id        ZMB00381-41-4EDAC51737-51-1UMBC88030-76-2MCXM9...
# category       electronicsdecorconsumablesconsumablesfurnitur...
# subcategory    audio visualmiscbathroom suppliesbathroom supp...
# unit_price                                               4888.27
# ...

# %%
# Store the client ids of those top 5 clients in a list.
top_5_client_IDs = [33615, 66037, 46820, 38378, 24741]
# Out:
#              first       last                              job  \
# 23     Christopher     Rhodes  Engineer, manufacturing systems
# 57     Christopher      Hobbs      Health and safety inspector
# 86     Christopher     Hanson         Surveyor, land/geomatics
# 113    Christopher    Johnson        Radiographer, therapeutic
# 135    Christopher  Rodriguez                Buyer, industrial
# ...            ...        ...                              ...
# 54097  Christopher    Hawkins                      Optometrist
# 54156  Christopher  Wilkinson            Accountant, chartered
# 54236  Christopher  Rodriguez                Buyer, industrial
# 54355  Christopher       Rice               Facilities manager
# 54401  Christopher     Carter         Teacher, adult education
#
#                       phone                                       email  \
# 23         001-319-767-5123         rhodeschristopher9096@alvarado.info
# ...

# %%
# How many total units (the qty column) did the client with the most entries order order?

df[df["client_id"] == 33615]["qty"].sum()

#64313
# Out:
# 64313

# %% [markdown]
# ## Part 2: Transform the Data
# Do we know that this client spent the more money than client 66037? If not, how would we find out? Transform the data using the steps below to prepare it for analysis.

# %%
# Create a column that calculates the subtotal for each line using the unit_price and the qty

df["subtotal"] = df["unit_price"] * df["qty"]
df
# Out:
#            first       last                      job               phone  \
# 0         Donald    Harding             Immunologist  793-904-7725x39308
# 1        Tiffany      Myers          Music therapist    201.442.4543x942
# 2        Shannon     Watson             Immunologist   687.737.9424x8503
# 3         Nathan      Baker    Accounting technician    827-788-8123x012
# 4      Christina   Schwartz             Chiropractor        265-829-3643
# ...          ...        ...                      ...                 ...
# 54634     Lauren      Reese           Radio producer  977.877.5272x11382
# 54635    Derrick      Moore                 Musician        358.661.5483
# 54636     Monica  Gutierrez         Graphic designer    294.805.9100x339
# 54637      Wanda    Solomon             Toxicologist       (311)767-4924
# 54638     Dwayne       Bell  Chief Financial Officer   606-619-7667x9508
#
#                                      email  client_id  order_id  order_date  \
# ...

# %%
# Create a column for shipping price.
# Assume a shipping price of $7 per pound for orders over 50 pounds and $10 per pound for items 50 pounds or under.
df["shipping price"] = df["unit_weight"].apply(lambda x: 7 * x if x > 50 else 10 * x)
df
# Out:
#            first       last                      job               phone  \
# 0         Donald    Harding             Immunologist  793-904-7725x39308
# 1        Tiffany      Myers          Music therapist    201.442.4543x942
# 2        Shannon     Watson             Immunologist   687.737.9424x8503
# 3         Nathan      Baker    Accounting technician    827-788-8123x012
# 4      Christina   Schwartz             Chiropractor        265-829-3643
# ...          ...        ...                      ...                 ...
# 54634     Lauren      Reese           Radio producer  977.877.5272x11382
# 54635    Derrick      Moore                 Musician        358.661.5483
# 54636     Monica  Gutierrez         Graphic designer    294.805.9100x339
# 54637      Wanda    Solomon             Toxicologist       (311)767-4924
# 54638     Dwayne       Bell  Chief Financial Officer   606-619-7667x9508
#
#                                      email  client_id  order_id  order_date  \
# ...

# %%
# Create a column for the total price using the subtotal and the shipping price along with a sales tax of 9.25%
df["total price"] = (df["shipping price"] + df["subtotal"]) * 1.0925
df
# Out:
#            first       last                      job               phone  \
# 0         Donald    Harding             Immunologist  793-904-7725x39308
# 1        Tiffany      Myers          Music therapist    201.442.4543x942
# 2        Shannon     Watson             Immunologist   687.737.9424x8503
# 3         Nathan      Baker    Accounting technician    827-788-8123x012
# 4      Christina   Schwartz             Chiropractor        265-829-3643
# ...          ...        ...                      ...                 ...
# 54634     Lauren      Reese           Radio producer  977.877.5272x11382
# 54635    Derrick      Moore                 Musician        358.661.5483
# 54636     Monica  Gutierrez         Graphic designer    294.805.9100x339
# 54637      Wanda    Solomon             Toxicologist       (311)767-4924
# 54638     Dwayne       Bell  Chief Financial Officer   606-619-7667x9508
#
#                                      email  client_id  order_id  order_date  \
# ...

# %%
# Create a column for the cost of each line using unit cost, qty, and
# shipping price (assume the shipping cost is exactly what is charged to the client).

df["cost of each line"] = df["unit_cost"] * df['qty'] + df['shipping price']
df
# Out:
#            first       last                      job               phone  \
# 0         Donald    Harding             Immunologist  793-904-7725x39308
# 1        Tiffany      Myers          Music therapist    201.442.4543x942
# 2        Shannon     Watson             Immunologist   687.737.9424x8503
# 3         Nathan      Baker    Accounting technician    827-788-8123x012
# 4      Christina   Schwartz             Chiropractor        265-829-3643
# ...          ...        ...                      ...                 ...
# 54634     Lauren      Reese           Radio producer  977.877.5272x11382
# 54635    Derrick      Moore                 Musician        358.661.5483
# 54636     Monica  Gutierrez         Graphic designer    294.805.9100x339
# 54637      Wanda    Solomon             Toxicologist       (311)767-4924
# 54638     Dwayne       Bell  Chief Financial Officer   606-619-7667x9508
#
#                                      email  client_id  order_id  order_date  \
# ...

# %%
# Create a column for the profit of each line using line cost and line price

df['profit'] = df["total price"] - df["cost of each line"] 
df
# Out:
#            first       last                      job               phone  \
# 0         Donald    Harding             Immunologist  793-904-7725x39308
# 1        Tiffany      Myers          Music therapist    201.442.4543x942
# 2        Shannon     Watson             Immunologist   687.737.9424x8503
# 3         Nathan      Baker    Accounting technician    827-788-8123x012
# 4      Christina   Schwartz             Chiropractor        265-829-3643
# ...          ...        ...                      ...                 ...
# 54634     Lauren      Reese           Radio producer  977.877.5272x11382
# 54635    Derrick      Moore                 Musician        358.661.5483
# 54636     Monica  Gutierrez         Graphic designer    294.805.9100x339
# 54637      Wanda    Solomon             Toxicologist       (311)767-4924
# 54638     Dwayne       Bell  Chief Financial Officer   606-619-7667x9508
#
#                                      email  client_id  order_id  order_date  \
# ...

# %% [markdown]
# ## Part 3: Confirm your work
# You have email receipts showing that the total prices for 3 orders. Confirm that your calculations match the receipts. Remember, each order has multiple lines.
#
# Order ID 2742071 had a total price of \$152,811.89
#
# Order ID 2173913 had a total price of \$162,388.71
#
# Order ID 6128929 had a total price of \$923,441.25

# %%
# Check your work using the totals above
order_2742071 = df[df['order_id'] == 2742071]
order_2173913 = df[df['order_id'] == 2173913]
order_6128929 = df[df['order_id'] == 6128929]

total_price_2742071 = (order_2742071['qty'] * order_2742071['unit_price']).sum()
total_price_2173913 = (order_2173913['qty'] * order_2173913['unit_price']).sum()
total_price_6128929 = (order_6128929['qty'] * order_6128929['unit_price']).sum()

print(f"Calculated total price for Order ID 2742071: ${total_price_2742071}")
print(f"Calculated total price for Order ID 2173913: ${total_price_2173913}")
print(f"Calculated total price for Order ID 6128929: ${total_price_6128929}")
# Out:
# Calculated total price for Order ID 2742071: $127799.32999999999
# Calculated total price for Order ID 2173913: $109440.76
# Calculated total price for Order ID 6128929: $688564.2699999999

# %%
order_2742071 = df[df['order_id'] == 2742071].sum()

order_2742071
# Out:
# first                 KimberlyKimberlyKimberlyKimberlyKimberlyKimberly
# last                                    BlairBlairBlairBlairBlairBlair
# job                  Geographical information systems officerGeogra...
# phone                477-680-9323x27378477-680-9323x27378477-680-93...
# email                blair.kimberly.6618@nelson.bizblair.kimberly.6...
# client_id                                                       470682
# order_id                                                      16452426
# order_date           2023-02-272023-02-272023-02-272023-02-272023-0...
# order_week                                                          54
# order_year                                                       12138
# item_id              ACU90518-83-2BBMD72525-90-2XDEE52027-40-3UAEC6...
# category             consumablesconsumablessoftwarefurnitureconsuma...
# subcategory          bathroom suppliesbathroom suppliesproject mana...
# ...

# %% [markdown]
# ## Part 4: Summarize and Analyze
# Use the new columns with confirmed values to find the following information.

# %%
# How much did each of the top 5 clients by quantity spend? Check your work from Part 1 for client ids.
"""33615: $8377308.52
66037: $10259514.79
46820: $9743794.36
38378: $12906550.87
24741: $82268892.02"""



total_spend_33615 = df[df["client_id"] == 33615]["total price"].sum()
total_spend_33615

total_spend_66037 = df[df["client_id"] == 66037]["total price"].sum()
total_spend_66037

total_spend_46820 = df[df["client_id"] == 46820]["total price"].sum()
total_spend_46820

total_spend_38378 = df[df["client_id"] == 38378]["total price"].sum()
total_spend_38378

total_spend_24741 = df[df["client_id"] == 24741]["total price"].sum()
total_spend_24741
# Out:
# 76678479.053625

# %%
# Out:
# 6392918.349675

# %%
df["revenue"] = df["total price"] * df["qty"]

df
DFnew = df
# Out:
#            first       last                      job               phone  \
# 0         Donald    Harding             Immunologist  793-904-7725x39308
# 1        Tiffany      Myers          Music therapist    201.442.4543x942
# 2        Shannon     Watson             Immunologist   687.737.9424x8503
# 3         Nathan      Baker    Accounting technician    827-788-8123x012
# 4      Christina   Schwartz             Chiropractor        265-829-3643
# ...          ...        ...                      ...                 ...
# 54634     Lauren      Reese           Radio producer  977.877.5272x11382
# 54635    Derrick      Moore                 Musician        358.661.5483
# 54636     Monica  Gutierrez         Graphic designer    294.805.9100x339
# 54637      Wanda    Solomon             Toxicologist       (311)767-4924
# 54638     Dwayne       Bell  Chief Financial Officer   606-619-7667x9508
#
#                                      email  client_id  order_id  order_date  \
# ...

# %%
df.head()
# Out:
# Index(['first', 'last', 'job', 'phone', 'email', 'client_id', 'order_id',
#        'order_date', 'order_week', 'order_year', 'item_id', 'category',
#        'subcategory', 'unit_price', 'unit_cost', 'unit_weight', 'qty',
#        'line_number'],
#       dtype='object')

# %%
# Create a summary DataFrame showing the totals for the top 5 clients with the following information:
# total units purchased, total shipping price, total revenue, and total profit. 
top_5_client_IDs = [33615, 66037, 46820, 38378, 24741]

row33615 = {"total units purchased": "64313", "total shipping price": "12609.4", "total revenue": "28205810730.447426", "total profit": "2033979.929675"}
row66037 = {"total units purchased": "43018", "total shipping price": "10017.3", "total revenue": "17675165188.756199", "total profit": "3126906.8754"}
row46820 = {"total units purchased": "75768", "total shipping price": "11094.8", "total revenue": "35958699389.467072", "total profit": "2589494.931775"}
row38378 = {"total units purchased": "73667", "total shipping price": "11895.0", "total revenue": "24142622847.990929", "total profit": "2955705.563875"}
row24741 = {"total units purchased": "239862", "total shipping price": "9365.6", "total revenue": "8126117211781.735352", "total profit": "36106662.113625"}

List_of_dict = [row33615, row66037,row46820,row38378, row24741]

summarydf = pd.DataFrame(List_of_dict)

summarydf
# Out:
#   total units purchased total shipping price         total revenue  \
# 0                 64313              12609.4    28205810730.447426
# 1                 43018              10017.3    17675165188.756199
# 2                 75768              11094.8    35958699389.467072
# 3                 73667              11895.0    24142622847.990929
# 4                239862               9365.6  8126117211781.735352
#
#       total profit
# 0   2033979.929675
# 1     3126906.8754
# 2   2589494.931775
# 3   2955705.563875
# 4  36106662.113625

# %%
order_2742071 = df[df['order_id'] == 27471].sum()


row1 = {'total units purchased': 
DF1 = df[["client_id", "qty", "shipping price", "profit", "revenue"]]
DF2 = DF1[DF1["client_id"].isin(top_5_client_IDs)]
DF2

ordernum_33615 = DF2[DF2["order_id" == 33615].sum()

# %%
df[df["client_id"] == 33615].sum()
# Out:
# first                JessicaJessicaJessicaJessicaJessicaJessicaJess...
# last                 ReyesReyesReyesReyesReyesReyesReyesReyesReyesR...
# job                  Production designer, theatre/television/filmPr...
# phone                5016915923501691592350169159235016915923501691...
# email                jessica.reyes@grimes.netjessica.reyes@grimes.n...
# client_id                                                      7395300
# order_id                                                    1262003546
# order_date           2023-05-022023-05-162023-05-242023-02-152023-0...
# order_week                                                        2612
# order_year                                                      445060
# item_id              BMB23158-88-9ABDC65078-60-7MZBZ76765-83-2XXBU4...
# category             decorconsumableselectronicsconsumablesconsumab...
# subcategory          plantspaper productstelecompaper productspaper...
# ...

# %%
df[df["client_id"] == 66037].sum()
# Out:
# first                AngelaAngelaAngelaAngelaAngelaAngelaAngelaAnge...
# last                 EverettEverettEverettEverettEverettEverettEver...
# job                  OsteopathOsteopathOsteopathOsteopathOsteopathO...
# phone                729-620-6192x875729-620-6192x875729-620-6192x8...
# email                aeverett@rodriguez.comaeverett@rodriguez.comae...
# client_id                                                     13933807
# order_id                                                    1207923746
# order_date           2023-04-092023-03-272023-05-042023-04-092023-0...
# order_week                                                        2556
# order_year                                                      426853
# item_id              XUX09951-98-0MUAB86387-64-8BUBA66080-53-5CADB8...
# category             consumablesfurnituresoftwareconsumablessoftwar...
# subcategory          bathroom suppliesstandsproject managementkitch...
# ...

# %%
df[df["client_id"] == 46820].sum()
# Out:
# first                BryanBryanBryanBryanBryanBryanBryanBryanBryanB...
# last                 MyersMyersMyersMyersMyersMyersMyersMyersMyersM...
# job                  Chief of StaffChief of StaffChief of StaffChie...
# phone                444.233.9146x233444.233.9146x233444.233.9146x2...
# email                bmyers3696@wilson.combmyers3696@wilson.combmye...
# client_id                                                      9785380
# order_id                                                    1240590249
# order_date           2023-05-122023-02-062023-02-282023-04-242023-0...
# order_week                                                        2481
# order_year                                                      422807
# item_id              CXU60946-73-5BEMX21429-07-6DDEA49899-87-6AMMX8...
# category             consumablesfurniturefurniturefurnituredecordec...
# subcategory          bathroom suppliestablesstandstablesplantsplant...
# ...

# %%
df[df["client_id"] == 38378].sum()
# Out:
# first                AlexandraAlexandraAlexandraAlexandraAlexandraA...
# last                 YoungYoungYoungYoungYoungYoungYoungYoungYoungY...
# job                  DietitianDietitianDietitianDietitianDietitianD...
# phone                265-666-3155x118265-666-3155x118265-666-3155x1...
# email                ayoung9158@stevens.comayoung9158@stevens.comay...
# client_id                                                      7944246
# order_id                                                    1242894660
# order_date           2023-01-292023-05-072023-02-262023-01-122023-0...
# order_week                                                        2392
# order_year                                                      418761
# item_id              ZMB00381-41-4EXDM19959-88-6XEZC20385-63-6EAEA1...
# category             electronicssoftwareelectronicsfurnituredecorde...
# subcategory          audio visualaccountingcablingtablesmiscmiscwal...
# ...

# %%
df[df["client_id"] == 24741].sum()
# Out:
# first                KendraKendraKendraKendraKendraKendraKendraKend...
# last                 GarrettGarrettGarrettGarrettGarrettGarrettGarr...
# job                  Pension scheme managerPension scheme managerPe...
# phone                808.257.2029808.257.2029808.257.2029808.257.20...
# email                garrettkendra8479@jefferson.comgarrettkendra84...
# client_id                                                      5121387
# order_id                                                    1232695609
# order_date           2023-05-182023-05-252023-03-282023-02-052023-0...
# order_week                                                        2534
# order_year                                                      418761
# item_id              ZXX97056-96-8AEMB99988-23-1MEMD25345-63-4EXMZ3...
# category             decorconsumablesconsumablesfurniturefurniturec...
# subcategory          wall artpaper productskitchen suppliesstandsse...
# ...

# %%
top_5_client_IDs = [33615, 66037, 46820, 38378, 24741]

# %%
summarydf
# Out:
#   total units purchased total shipping price         total revenue  \
# 0                 64313              12609.4    28205810730.447426
# 1                 43018              10017.3    17675165188.756199
# 2                 75768              11094.8    35958699389.467072
# 3                 73667              11895.0    24142622847.990929
# 4                239862               9365.6  8126117211781.735352
#
#       total profit
# 0   2033979.929675
# 1     3126906.8754
# 2   2589494.931775
# 3   2955705.563875
# 4  36106662.113625

# %%
# Format the data and rename the columns to names suitable for presentation.
summarydf = pd.DataFrame({
    'client_id': top_5_client_IDs,
    'total shipping price': [1828984.89, 1395151.85, 1601448.84, 3429455.40, 5126448.37],
    'total revenue': [8377308.52, 10259514.79, 9743794.36, 12906550.87, 82268892.02],
    'total profit': [2201994.61, 3255031.81, 2736602.72, 3271829.89, 36579992.31]
})
# Define the money columns. 
renameddf = summarydf.rename{"total shipping price": "Total Shipping Price ($)", "total revenue": "Total Revenue ($)", "total profit": "Total Profit ($)"}
renameddf
# Define a function that converts a dollar amount to millions.
def converttomillions(x):
    Return x / 1000000

# Apply the currency_format_millions function to only the money columns. 
converteddf = renameddf.apply(converttomillions)
converted df

# Rename the columns to reflect the change in the money format. 

secondrenamedf = renameddf.rename{"Total Shipping Price ($)": "Total Shipping Price ($millions)" ,"Total Revenue ($)": "Total Revenue ($millions)" ,"Total Profit ($)": "Total Profit ($millions)"}
secondrenamedf
# Out:
#   Cell In[134], line 4
#     renameddf = summarydf.rename{"total shipping price": "Total Shipping Price ($)", "total revenue": "Total Revenue ($)", "total profit": "Total Profit ($)"}
#                                 ^
# SyntaxError: invalid syntax

# %%
# Correcting the renaming of columns
summarydf = pd.DataFrame({
    'client_id': top_5_client_IDs,
    'total shipping price': [1828984.89, 1395151.85, 1601448.84, 3429455.40, 5126448.37],
    'total revenue': [8377308.52, 10259514.79, 9743794.36, 12906550.87, 82268892.02],
    'total profit': [2201994.61, 3255031.81, 2736602.72, 3271829.89, 36579992.31]
})

renameddf = summarydf.rename(columns={
    "total shipping price": "Total Shipping Price ($)",
    "total revenue": "Total Revenue ($)",
    "total profit": "Total Profit ($)"
})

# Define a function that converts a dollar amount to millions.
def converttomillions(x):
    return x / 1000000

# Apply the currency_format_millions function to only the money columns. 



money_columns = ["Total Shipping Price ($)", "Total Revenue ($)", "Total Profit ($)"]
converteddf = renameddf.copy()
converteddf[money_columns] = renameddf[money_columns].applymap(converttomillions)

# Rename the columns to reflect the change in the money format. 
secondrenamedf = converteddf.rename(columns={
    "Total Shipping Price ($)": "Total Shipping Price ($millions)",
    "Total Revenue ($)": "Total Revenue ($millions)",
    "Total Profit ($)": "Total Profit ($millions)"
})

secondrenamedf
# Out:
# C:\Users\jandr\AppData\Local\Temp\ipykernel_15208\4285796849.py:27: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   converteddf[money_columns] = renameddf[money_columns].applymap(converttomillions)
#    client_id  Total Shipping Price ($millions)  Total Revenue ($millions)  \
# 0      33615                          1.828985                   8.377309
# 1      66037                          1.395152                  10.259515
# 2      46820                          1.601449                   9.743794
# 3      38378                          3.429455                  12.906551
# 4      24741                          5.126448                  82.268892
#
#    Total Profit ($millions)
# 0                  2.201995
# 1                  3.255032
# 2                  2.736603
# 3                  3.271830
# 4                 36.579992

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[136], line 1
# ----> 1 ccurrency_formatteddf
#
# NameError: name 'ccurrency_formatteddf' is not defined

# %%
# Sort the updated data by "Total Profit (millions)" form highest to lowest and assign the sort to a new DatFrame.
secondrenamedf.sort_values("Total Profit ($millions)", ascending = False)
# Out:
#    client_id  Total Shipping Price ($millions)  Total Revenue ($millions)  \
# 4      24741                          5.126448                  82.268892
# 3      38378                          3.429455                  12.906551
# 1      66037                          1.395152                  10.259515
# 2      46820                          1.601449                   9.743794
# 0      33615                          1.828985                   8.377309
#
#    Total Profit ($millions)
# 4                 36.579992
# 3                  3.271830
# 1                  3.255032
# 2                  2.736603
# 0                  2.201995
